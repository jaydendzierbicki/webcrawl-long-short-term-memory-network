# %% [markdown]
# # 2-Data Wrangling Script
# Date created: 16/04/23
# Created by: Jayden Dzierbicki
# Last updated: 16/04/23
#
# The purpose of this notebook is to undertake the following in prepration for machine learning
# - Data wrangling and cleaning
# - NLP techniques
# - EDA
# - Clean data saved and stored into mySQL/csv

# %%
import getpass
from sqlalchemy import create_engine # For connecting to SQL databases
import pandas as pd

# Function to load data into mySQL
def extract_data_mySQL(database_name, table_name):
    user = 'root'

    # Prompt the user for a password
    password = getpass.getpass("Enter your MySQL password: ")
    host = 'localhost'
    port = 3306
    database = database_name
    engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

    # Write the DataFrame to a SQL table
    table_name =  table_name
    query = f"SELECT * FROM {table_name}"
    
    # Read query to dataframe
    df = pd.read_sql(query, engine)
    return(df)

    # Close the connection
    engine.dispose()

# %% [markdown]
# ## Data wrangling and cleaning
# - Load in data
# - Quick EDA of loaded data
# - Decsions based on EDA - period of analysis
# - Test and remove duplicates i.e. user could spam a forum board
# - NLP
#
# Decsions made in this section include:
# - Analysis from 2021-02-02 -> 2023-04-14: Limitations of data retrival for cryptocompare.com

# %%
# Load in data sources
cryptocompare_xrp = extract_data_mySQL('MA5851_A3', 'cryptocompare_xrp')
investingcom_xrp = extract_data_mySQL('MA5851_A3', 'investingcom_xrp')
xrp_price_yahoo = extract_data_mySQL('MA5851_A3', 'xrp_price_yahoo')
# Out:
# Enter your MySQL password: ········
# Enter your MySQL password: ········
# Enter your MySQL password: ········

# %%
def get_min_max_dates(table, table_name):
    print(f'Min and max date range of {table_name}')
    print(f'MIN Date: {table.date.min()}')
    print(f'MAX Date: {table.date.max()}')
    print("-----------------------------")


get_min_max_dates(cryptocompare_xrp, "cryptocompare_xrp")
get_min_max_dates(investingcom_xrp, "investingcom_xrp")
get_min_max_dates(xrp_price_yahoo, "xrp_price_yahoo")
# Out:
# Min and max date range of cryptocompare_xrp
# MIN Date: 2021-02-02
# MAX Date: 2023-04-14
# -----------------------------
# Min and max date range of investingcom_xrp
# MIN Date: 2018-03-16
# MAX Date: 2023-04-14
# -----------------------------
# Min and max date range of xrp_price_yahoo
# MIN Date: 2017-11-10 00:00:00
# MAX Date: 2023-04-14 00:00:00
# -----------------------------

# %%
# Filter all data by date range, using data from 2021-02-02 onwards
min_date_filter = pd.to_datetime('2021-02-02')  # Used to filter min date

def filter_by_min_date(date_filter, df, table_name):
    df['date'] = pd.to_datetime(df['date'])
    filtered_df = df[df['date'] >= date_filter]
    rows_removed = len(df) - len(filtered_df)
    print(f"Number of rows filtered by date from {table_name}: {rows_removed}")
    print("---------------------------------------------------------")
    return filtered_df

filtered_investingcom_xrp = filter_by_min_date(min_date_filter, investingcom_xrp, "investingcom_xrp")
filtered_xrp_price_yahoo = filter_by_min_date(min_date_filter, xrp_price_yahoo, "xrp_price_yahoo")
filtered_cryptocompare_xrp = filter_by_min_date(min_date_filter, cryptocompare_xrp, "cryptocompare_xrp")
# Out:
# Number of rows filtered by date from investingcom_xrp: 26268
# ---------------------------------------------------------
# Number of rows filtered by date from xrp_price_yahoo: 1180
# ---------------------------------------------------------
# Number of rows filtered by date from cryptocompare_xrp: 0
# ---------------------------------------------------------

# %%
# Remove NA observations from comments
def remove_na_values(df, table_name, variable):
    output = df.dropna(subset=[variable])
    rows_removed = len(df) - len(output)
    print(f"Number of NA rows removed from {table_name}: {rows_removed}")
    print("---------------------------------------------------------")
    return output

# Assuming cryptocompare_xrp is a pandas DataFrame with a 'comment' column
cleaned_cryptocompare_xrp = remove_na_values(filtered_investingcom_xrp, "cryptocompare_xrp", "comment")
cleaned_investingcom_xrp = remove_na_values(filtered_cryptocompare_xrp, "investingcom_xrp", "comment")
# Out:
# Number of NA rows removed from cryptocompare_xrp: 43
# ---------------------------------------------------------
# Number of NA rows removed from investingcom_xrp: 129
# ---------------------------------------------------------

# %%
def preview_duplicate_comments(df, table_name):
    # Find duplicates based on 'date' and 'comment' columns
    duplicates = df[df.duplicated(subset=['date', 'comment'], keep=False)]

    # Group the duplicates by 'date' and 'comment' columns and count their occurrences
    duplicate_counts = duplicates.groupby(['date', 'comment']).size().reset_index(name='count')

    # Sort the DataFrame by the 'count' column in descending order
    duplicate_counts_sorted = duplicate_counts.sort_values(by='count', ascending=False)

    # Print the count for each specific duplicate
    print(f"Duplicate preview for {table_name}")
    print(duplicate_counts_sorted)
    print("-------------------------------------------------------------------------")

def remove_duplicate_comments(df, table_name):
    # Remove duplicates
    unique_df = df.drop_duplicates(subset=['date', 'comment'])
    duplicates_removed = len(df) - len(unique_df)
    print(f'Number of duplicates removed from {table_name}: {duplicates_removed}')
    print("-------------------------------------------------------------------------")
    return unique_df

# Preview and remove duplicates
preview_duplicate_comments(cleaned_cryptocompare_xrp, "cleaned_cryptocompare_xrp")
preview_duplicate_comments(cleaned_investingcom_xrp, "cleaned_investingcom_xrp")

cleaned_cryptocompare_xrp_2 = remove_duplicate_comments(cleaned_cryptocompare_xrp, "cleaned_cryptocompare_xrp")
cleaned_investingcom_xrp_2 = remove_duplicate_comments(cleaned_investingcom_xrp, "cleaned_investingcom_xrp")
# Out:
# Duplicate preview for cleaned_cryptocompare_xrp
#           date                                            comment  count
# 124 2021-04-13                                                lol      6
# 96  2021-04-10                                                lol      5
# 38  2021-02-21                                            shut up      4
# 105 2021-04-11  My newbie opinion: if price break 1.3200, it m...      4
# 25  2021-02-14  Guys, how long do u suppose this place of resi...      4
# ..         ...                                                ...    ...
# 118 2021-04-13  Im not selling a penny till we beat the SEC an...      2
# 117 2021-04-13                                   Here we go again      2
# 116 2021-04-13                                              HODL🚀      2
# 115 2021-04-13                                              Bitso      2
# 337 2022-11-18  Exactly! Even 10% of swift business puts this ...      2
#
# [338 rows x 3 columns]
# -------------------------------------------------------------------------
# Duplicate preview for cleaned_investingcom_xrp
#         date                                            comment  count
# 9 2022-01-22                                         #freeveyor      7
# 0 2021-04-02  I want to Post a sun downer Photo of my flat b...      3
# 1 2021-04-14                                              run..      2
# 2 2021-05-04  Not the best start to a tuesday.. I’m still re...      2
# 3 2021-05-08                          The moment of 1000 truths      2
# 4 2021-05-16                                Today's a good day?      2
# 5 2021-05-17                                                ;-)      2
# 6 2021-06-29                Pump incoming\t\t\t\t\t\tView Edits      2
# 7 2021-10-27                            .\t\t\t\t\t\tView Edits      2
# 8 2021-12-22                                            Support      2
# -------------------------------------------------------------------------
# Number of duplicates removed from cleaned_cryptocompare_xrp: 375
# -------------------------------------------------------------------------
# Number of duplicates removed from cleaned_investingcom_xrp: 16
# -------------------------------------------------------------------------

# %%
# Join text data together retaining date, source and comment
text_data = pd.concat([cleaned_investingcom_xrp_2, cleaned_cryptocompare_xrp_2])[['date', 'source', 'comment']]

# create a new dataframe with the count of comments by date and source
count_data = text_data.groupby(['date', 'source']).size().reset_index(name='count')

# calculate the average number of posts per day - all sources
avg_posts_per_day = count_data.groupby('date')['count'].mean().mean()
print('Average number of posts per day: {:.2f}'.format(avg_posts_per_day))

# calculate the median number of posts per day - all sources
med_posts_per_day = count_data.groupby('date')['count'].median().median()
print('Median number of posts per day: {:.2f}'.format(med_posts_per_day))
# Out:
# Average number of posts per day: 24.84
# Median number of posts per day: 8.50

# %%
# Qucik EDA to undertsand distrubtion of 
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact, interactive
import numpy as np


# define a function that plots the count of comments for a given date range
def plot_comments(start_date, end_date):
    start_date = np.datetime64(start_date)
    end_date = np.datetime64(end_date)
    data = count_data[(count_data['date'] >= start_date) & (count_data['date'] <= end_date)]
    fig, ax = plt.subplots(figsize=(12, 6))
    for source in data['source'].unique():
        source_data = data[data['source'] == source]
        ax.plot(source_data['date'], source_data['count'], label=source)
    ax.set_xlabel('Date')
    ax.set_ylabel('Number of comments')
    ax.set_title('Number of comments by source and date')
    ax.legend()
    plt.show()


# create a date slider widget
start_date_widget = widgets.DatePicker(description='Start date:', value=min(count_data['date']))
end_date_widget = widgets.DatePicker(description='End date:', value=max(count_data['date']))

# create an interactive plot using the date slider widget
interactive_plot = interactive(plot_comments, start_date=start_date_widget, end_date=end_date_widget)
output = interactive_plot.children[-1]
output.layout.height = '400px'
interactive_plot
# Out:
# interactive(children=(DatePicker(value=Timestamp('2021-02-02 00:00:00'), description='Start date:'), DatePicke…

# %% [markdown]
# ### Graph Intepreation & Next steps:
# During the period between March and April of 2020-2021, there were significant developments in the legal battle between SEC and Ripple, which is reflected in the online forum discussions. This increase in discussions was particularly noticeable on the Cryptocompare platform, with a substantial spike during that period. For more information on the SEC vs. Ripple lawsuit, refer to this article: https://cointelegraph.com/learn/the-sec-vs-ripple-lawsuit-everything-you-need-to-know.
#
# #### At this stage we have commpleted the following tasks:
# - Filtered all data
# - Remove missing observations
# - Remove duplicates
# - Joined text data together & quick EDA of sample distrubtion
#
# #### The next stages will invlove:
# - Text cleanining (unwanted characters, HTML elements, conver to lower case etc)
# - Tokenization (Tokenize the text data into indivdual workds or tokens)
# - Stopword removal (debating as this can loose meaning of word)
# - Lemmatization or stemming (debating)
# - Embedding matrix?

# %%
import re
import pandas as pd
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))



def clean_text(text):
    # Remove backslash-apostrophe 
    text = re.sub("\'", "", text) 
    # Remove everything except alphabets 
    #text = re.sub("[^a-zA-Z]"," ",text) 
    # Remove whitespaces 
    text = ' '.join(text.split()) 
    # Convert text to lowercase 
    text = text.lower() 
    text = word_tokenize(text)
    return text



def clean_text(text):
    # Remove backslash-apostrophe 
    text = re.sub("\'", "", text) 
    # Remove everything except alphabets 
    #text = re.sub("[^a-zA-Z]"," ",text) 
    # Remove whitespaces 
    text = ' '.join(text.split()) 
    # Convert text to lowercase 
    text = text.lower() 
    text = ' '.join(word_tokenize(text))
    return text

def remove_stopwords_and_stem(text):
#    # Remove stop words and stem words
    stemmer = PorterStemmer()
    tokens = word_tokenize(text.lower())
#    no_stopword_text = [stemmer.stem(w) for w in tokens if not w in stop_words]
    return ' '.join(no_stopword_text)


#def clean_text(text ): 
 #   delete_dict = {sp_character: ' ' for sp_character in string.punctuation} 
 #   delete_dict[' '] = ' ' 
 #   table = str.maketrans(delete_dict)
 #   text1 = text.translate(table)
 #   #print('cleaned:'+text1)
 #   textArr= text1.split()
 #   text2 = ' '.join([w for w in textArr if ( not w.isdigit() and  ( not w.isdigit() and len(w)>2))]) 
    
 #   return text2.lower().split(' ')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jayde\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayde\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Clean all the comments in the 'comment' column of the DataFrame
text_data['cleaned_comment'] = text_data['comment'].apply(clean_text)
#text_data['cleaned_comment'] = text_data['cleaned_comment'].apply(remove_stopwords_and_stem)
text_data
# Out:
#             date                                         source  \
# 0     2023-04-14  https://www.cryptocompare.com/coins/xrp/forum
# 1     2023-04-14  https://www.cryptocompare.com/coins/xrp/forum
# 2     2023-04-14  https://www.cryptocompare.com/coins/xrp/forum
# 3     2023-04-13  https://www.cryptocompare.com/coins/xrp/forum
# 4     2023-04-13  https://www.cryptocompare.com/coins/xrp/forum
# ...          ...                                            ...
# 33475 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33476 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33477 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33478 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33479 2021-02-02      https://www.investing.com/crypto/xrp/chat
#
#                                                  comment  \
# 0      moon soon, coon. mark my words (lol idk - no f...
# 1                               Boring xrp at the Moment
# 2      So bankrupted FTX….they recover $7.3 billion i...
# 3      Is UMU what many thought XRP was going to be u...
# 4      Coinbase just deposited Flare into my account....
# ...                                                  ...
# 33475                                        XRP=PORTELO
# 33476                    new smart move is xlm stellar!✌
# 33477                           xlm is not scammy enough
# 33478                                              buyyy
# 33479  Start Crypto Currency trading. Click below lin...
#
#                                          cleaned_comment
# 0      moon soon , coon . mark my words ( lol idk - n...
# 1                               boring xrp at the moment
# 2      so bankrupted ftx….they recover $ 7.3 billion ...
# 3      is umu what many thought xrp was going to be u...
# 4      coinbase just deposited flare into my account ...
# ...                                                  ...
# 33475                                        xrp=portelo
# 33476                  new smart move is xlm stellar ! ✌
# 33477                           xlm is not scammy enough
# 33478                                              buyyy
# 33479  start crypto currency trading . click below li...
#
# [39319 rows x 4 columns]

# %%
import pandas as pd
import emoji
import pandas as pd
import emoji


# Define a function to check if a string contains emojis
def has_emoji(text):
    for character in text:
        if emoji.emoji_count(character) > 0:
            return True
    return False

# Create a new DataFrame containing only the rows with emojis
emoji_df = text_data[text_data["comment"].apply(has_emoji)]
emoji_df
# Out:
#             date                                         source  \
# 2     2023-04-14  https://www.cryptocompare.com/coins/xrp/forum
# 7     2023-04-11  https://www.cryptocompare.com/coins/xrp/forum
# 13    2023-04-10  https://www.cryptocompare.com/coins/xrp/forum
# 14    2023-04-09  https://www.cryptocompare.com/coins/xrp/forum
# 26    2023-04-04  https://www.cryptocompare.com/coins/xrp/forum
# ...          ...                                            ...
# 33395 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33402 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33428 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33443 2021-02-02      https://www.investing.com/crypto/xrp/chat
# 33476 2021-02-02      https://www.investing.com/crypto/xrp/chat
#
#                                                  comment  \
# 2      So bankrupted FTX….they recover $7.3 billion i...
# 7                          This might be interesting 🤔🤔😎
# 13     What do you think will happen next?Thumbs up =...
# 14     For those that are still here😂🤣🤷‍♂️ (I’m not g...
# 26                           So how far is to the moon 🙃
# ...                                                  ...
# 33395  i just can’t wait for the day when it finally ...
# 33402  Lol The hopeless is talking. Everyone listen h...
# 33428  Free Dogecoin mining sign up on this site star...
# 33443                                               ok 🤡
# 33476                    new smart move is xlm stellar!✌
#
#                                          cleaned_comment
# 2      [so, bankrupted, ftx….they, recover, $, 7.3, b...
# 7                    [this, might, be, interesting, 🤔🤔😎]
# 13     [what, do, you, think, will, happen, next, ?, ...
# 14     [for, those, that, are, still, here😂🤣🤷‍♂️, (, ...
# 26                  [so, how, far, is, to, the, moon, 🙃]
# ...                                                  ...
# 33395  [i, just, can, ’, t, wait, for, the, day, when...
# 33402  [lol, the, hopeless, is, talking, ., everyone,...
# 33428  [free, dogecoin, mining, sign, up, on, this, s...
# 33443                                            [ok, 🤡]
# 33476         [new, smart, move, is, xlm, stellar, !, ✌]
#
# [2886 rows x 4 columns]

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Loop through each row of the DataFrame and calculate the sentiment score for each comment
for index, row in text_data.iterrows():
    comment = row['cleaned_comment']
    scores = sia.polarity_scores(comment)
    print(f"cleaned_comment {index+1}:", scores)
text_data['sentiment_score'] = text_data['cleaned_comment'].apply(lambda x: sia.polarity_scores(x)['compound'])
# Out:
# cleaned_comment 1: {'neg': 0.125, 'neu': 0.625, 'pos': 0.25, 'compound': 0.34}
# cleaned_comment 2: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 3: {'neg': 0.275, 'neu': 0.534, 'pos': 0.191, 'compound': -0.2732}
# cleaned_comment 4: {'neg': 0.05, 'neu': 0.705, 'pos': 0.245, 'compound': 0.9042}
# cleaned_comment 5: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 6: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 7: {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.4939}
# cleaned_comment 8: {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.4588}
# cleaned_comment 9: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
# cleaned_comment 10: {'neg': 0.067, 'neu': 0.821, 'pos': 0.111, 'compound': 0.3612}
# cleaned_comment 11: {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.2732}
# cleaned_comment 12: {'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.0772}
# cleaned_comment 13: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 14: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 15: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 16: {'neg': 0.195, 'neu': 0.71, 'pos': 0.095, 'compound': -0.1779}
# cleaned_comment 17: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.7845}
# cleaned_comment 18: {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.9349}
# cleaned_comment 19: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 20: {'neg': 0.348, 'neu': 0.53, 'pos': 0.121, 'compound': -0.4588}
# cleaned_comment 21: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 22: {'neg': 0.093, 'neu': 0.556, 'pos': 0.352, 'compound': 0.8316}
# cleaned_comment 23: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 24: {'neg': 0.122, 'neu': 0.745, 'pos': 0.133, 'compound': 0.0516}
# cleaned_comment 25: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 26: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 27: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 28: {'neg': 0.0, 'neu': 0.551, 'pos': 0.449, 'compound': 0.6908}
# cleaned_comment 29: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 30: {'neg': 0.106, 'neu': 0.761, 'pos': 0.133, 'compound': 0.4378}
# cleaned_comment 31: {'neg': 0.153, 'neu': 0.565, 'pos': 0.282, 'compound': 0.1531}
# cleaned_comment 32: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33: {'neg': 0.088, 'neu': 0.662, 'pos': 0.249, 'compound': 0.6249}
# cleaned_comment 34: {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3182}
# cleaned_comment 35: {'neg': 0.143, 'neu': 0.526, 'pos': 0.331, 'compound': 0.3612}
# cleaned_comment 36: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 37: {'neg': 0.269, 'neu': 0.571, 'pos': 0.16, 'compound': -0.2263}
# cleaned_comment 38: {'neg': 0.773, 'neu': 0.227, 'pos': 0.0, 'compound': -0.5267}
# cleaned_comment 39: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 40: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 41: {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 42: {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939}
# cleaned_comment 43: {'neg': 0.141, 'neu': 0.524, 'pos': 0.335, 'compound': 0.5859}
# cleaned_comment 44: {'neg': 0.053, 'neu': 0.762, 'pos': 0.185, 'compound': 0.9062}
# cleaned_comment 45: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 46: {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'compound': -0.2263}
# cleaned_comment 47: {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.5267}
# cleaned_comment 48: {'neg': 0.148, 'neu': 0.645, 'pos': 0.206, 'compound': 0.2263}
# cleaned_comment 49: {'neg': 0.0, 'neu': 0.947, 'pos': 0.053, 'compound': 0.2263}
# cleaned_comment 50: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 51: {'neg': 0.0, 'neu': 0.945, 'pos': 0.055, 'compound': 0.0258}
# cleaned_comment 52: {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.3818}
# cleaned_comment 53: {'neg': 0.19, 'neu': 0.571, 'pos': 0.238, 'compound': 0.128}
# cleaned_comment 54: {'neg': 0.16, 'neu': 0.84, 'pos': 0.0, 'compound': -0.2263}
# cleaned_comment 55: {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.128}
# cleaned_comment 56: {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.4588}
# cleaned_comment 57: {'neg': 0.313, 'neu': 0.687, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 58: {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.25}
# cleaned_comment 59: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# cleaned_comment 60: {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.5574}
# cleaned_comment 61: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 62: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 63: {'neg': 0.051, 'neu': 0.765, 'pos': 0.183, 'compound': 0.5679}
# cleaned_comment 64: {'neg': 0.0, 'neu': 0.149, 'pos': 0.851, 'compound': 0.6908}
# cleaned_comment 65: {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.0258}
# cleaned_comment 66: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 67: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.3612}
# cleaned_comment 68: {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 69: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 70: {'neg': 0.183, 'neu': 0.541, 'pos': 0.276, 'compound': 0.3818}
# cleaned_comment 71: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 72: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 73: {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.4588}
# cleaned_comment 74: {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 75: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 77: {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.2263}
# cleaned_comment 79: {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
# cleaned_comment 80: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 81: {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'compound': -0.2263}
# cleaned_comment 82: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# cleaned_comment 83: {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4019}
# cleaned_comment 84: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 85: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.3612}
# cleaned_comment 86: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 87: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.5994}
# cleaned_comment 88: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 89: {'neg': 0.287, 'neu': 0.556, 'pos': 0.157, 'compound': -0.5859}
# cleaned_comment 90: {'neg': 0.304, 'neu': 0.261, 'pos': 0.435, 'compound': 0.128}
# cleaned_comment 91: {'neg': 0.688, 'neu': 0.312, 'pos': 0.0, 'compound': -0.296}
# cleaned_comment 92: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 93: {'neg': 0.165, 'neu': 0.676, 'pos': 0.159, 'compound': -0.0516}
# cleaned_comment 94: {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.6369}
# cleaned_comment 95: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 96: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 97: {'neg': 0.142, 'neu': 0.808, 'pos': 0.05, 'compound': -0.5267}
# cleaned_comment 98: {'neg': 0.142, 'neu': 0.858, 'pos': 0.0, 'compound': -0.7269}
# cleaned_comment 99: {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.4939}
# cleaned_comment 100: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 101: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 102: {'neg': 0.224, 'neu': 0.776, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 103: {'neg': 0.722, 'neu': 0.278, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 104: {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.4404}
# cleaned_comment 105: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 106: {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# cleaned_comment 107: {'neg': 0.649, 'neu': 0.351, 'pos': 0.0, 'compound': -0.5719}
# cleaned_comment 108: {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}
# cleaned_comment 109: {'neg': 0.177, 'neu': 0.34, 'pos': 0.483, 'compound': 0.6705}
# cleaned_comment 110: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.5574}
# cleaned_comment 111: {'neg': 0.178, 'neu': 0.585, 'pos': 0.237, 'compound': 0.4245}
# cleaned_comment 112: {'neg': 0.348, 'neu': 0.652, 'pos': 0.0, 'compound': -0.1531}
# cleaned_comment 113: {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.6249}
# cleaned_comment 114: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 115: {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.0772}
# cleaned_comment 116: {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}
# cleaned_comment 117: {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'compound': 0.7845}
# cleaned_comment 118: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 119: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 120: {'neg': 0.223, 'neu': 0.311, 'pos': 0.466, 'compound': 0.6908}
# cleaned_comment 121: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 122: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 123: {'neg': 0.315, 'neu': 0.685, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 124: {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.5994}
# cleaned_comment 125: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 126: {'neg': 0.375, 'neu': 0.625, 'pos': 0.0, 'compound': -0.5574}
# cleaned_comment 127: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 128: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 129: {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.5859}
# cleaned_comment 130: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 131: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 132: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 133: {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.6808}
# cleaned_comment 134: {'neg': 0.608, 'neu': 0.392, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 135: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 136: {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 137: {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 138: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 139: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 140: {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.0772}
# cleaned_comment 141: {'neg': 0.101, 'neu': 0.821, 'pos': 0.078, 'compound': -0.1531}
# cleaned_comment 142: {'neg': 0.192, 'neu': 0.632, 'pos': 0.176, 'compound': -0.4184}
# cleaned_comment 143: {'neg': 0.295, 'neu': 0.513, 'pos': 0.192, 'compound': -0.3818}
# cleaned_comment 144: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 145: {'neg': 0.033, 'neu': 0.821, 'pos': 0.146, 'compound': 0.802}
# cleaned_comment 146: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.1531}
# cleaned_comment 147: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 148: {'neg': 0.144, 'neu': 0.726, 'pos': 0.131, 'compound': -0.2023}
# cleaned_comment 150: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 151: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 152: {'neg': 0.149, 'neu': 0.806, 'pos': 0.045, 'compound': -0.7184}
# cleaned_comment 153: {'neg': 0.371, 'neu': 0.431, 'pos': 0.198, 'compound': -0.25}
# cleaned_comment 154: {'neg': 0.047, 'neu': 0.88, 'pos': 0.073, 'compound': 0.0516}
# cleaned_comment 155: {'neg': 0.14, 'neu': 0.698, 'pos': 0.163, 'compound': 0.4019}
# cleaned_comment 156: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 157: {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# cleaned_comment 158: {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.5267}
# cleaned_comment 159: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 160: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.4588}
# cleaned_comment 161: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# cleaned_comment 162: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 163: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 164: {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
# cleaned_comment 165: {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 166: {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
# cleaned_comment 167: {'neg': 0.209, 'neu': 0.633, 'pos': 0.158, 'compound': -0.2023}
# cleaned_comment 168: {'neg': 0.697, 'neu': 0.303, 'pos': 0.0, 'compound': -0.5559}
# cleaned_comment 169: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 170: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 171: {'neg': 0.117, 'neu': 0.787, 'pos': 0.096, 'compound': -0.2023}
# cleaned_comment 172: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 173: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 174: {'neg': 0.115, 'neu': 0.531, 'pos': 0.354, 'compound': 0.6597}
# cleaned_comment 175: {'neg': 0.337, 'neu': 0.385, 'pos': 0.279, 'compound': -0.1531}
# cleaned_comment 176: {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.0572}
# cleaned_comment 177: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 178: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 179: {'neg': 0.089, 'neu': 0.73, 'pos': 0.182, 'compound': 0.8807}
# cleaned_comment 180: {'neg': 0.247, 'neu': 0.753, 'pos': 0.0, 'compound': -0.5574}
# cleaned_comment 181: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 182: {'neg': 0.095, 'neu': 0.868, 'pos': 0.036, 'compound': -0.4767}
# cleaned_comment 183: {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.296}
# cleaned_comment 184: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 185: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 186: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 187: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 188: {'neg': 0.0, 'neu': 0.911, 'pos': 0.089, 'compound': 0.5267}
# cleaned_comment 189: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# cleaned_comment 190: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 191: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 192: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# cleaned_comment 193: {'neg': 0.091, 'neu': 0.776, 'pos': 0.132, 'compound': 0.2263}
# cleaned_comment 194: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 195: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 196: {'neg': 0.248, 'neu': 0.567, 'pos': 0.184, 'compound': -0.2263}
# cleaned_comment 197: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 198: {'neg': 0.043, 'neu': 0.917, 'pos': 0.04, 'compound': -0.0258}
# cleaned_comment 199: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 200: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 201: {'neg': 0.207, 'neu': 0.793, 'pos': 0.0, 'compound': -0.8074}
# cleaned_comment 203: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 204: {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.5267}
# cleaned_comment 205: {'neg': 0.139, 'neu': 0.77, 'pos': 0.091, 'compound': -0.0941}
# cleaned_comment 206: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 207: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 208: {'neg': 0.128, 'neu': 0.743, 'pos': 0.128, 'compound': 0.0}
# cleaned_comment 209: {'neg': 0.078, 'neu': 0.719, 'pos': 0.204, 'compound': 0.4767}
# cleaned_comment 210: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 211: {'neg': 0.458, 'neu': 0.241, 'pos': 0.301, 'compound': -0.3182}
# cleaned_comment 212: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 213: {'neg': 0.055, 'neu': 0.869, 'pos': 0.077, 'compound': 0.2732}
# cleaned_comment 214: {'neg': 0.342, 'neu': 0.658, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 215: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 216: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.3818}
# cleaned_comment 217: {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.7184}
# cleaned_comment 218: {'neg': 0.0, 'neu': 0.535, 'pos': 0.465, 'compound': 0.1877}
# cleaned_comment 219: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 220: {'neg': 0.136, 'neu': 0.792, 'pos': 0.072, 'compound': -0.4019}
# cleaned_comment 221: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 222: {'neg': 0.1, 'neu': 0.696, 'pos': 0.203, 'compound': 0.1779}
# cleaned_comment 223: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 224: {'neg': 0.142, 'neu': 0.746, 'pos': 0.112, 'compound': -0.1027}
# cleaned_comment 225: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 226: {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.34}
# cleaned_comment 227: {'neg': 0.0, 'neu': 0.958, 'pos': 0.042, 'compound': 0.3612}
# cleaned_comment 228: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 229: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 230: {'neg': 0.195, 'neu': 0.41, 'pos': 0.395, 'compound': 0.5994}
# cleaned_comment 231: {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 232: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 233: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 235: {'neg': 0.0, 'neu': 0.383, 'pos': 0.617, 'compound': 0.6656}
# cleaned_comment 236: {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.2263}
# cleaned_comment 237: {'neg': 0.214, 'neu': 0.669, 'pos': 0.117, 'compound': -0.7845}
# cleaned_comment 238: {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.2263}
# cleaned_comment 239: {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.296}
# cleaned_comment 240: {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.6124}
# cleaned_comment 241: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# cleaned_comment 242: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6369}
# cleaned_comment 243: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6369}
# cleaned_comment 244: {'neg': 0.176, 'neu': 0.657, 'pos': 0.168, 'compound': -0.0274}
# cleaned_comment 245: {'neg': 0.095, 'neu': 0.793, 'pos': 0.111, 'compound': 0.1012}
# cleaned_comment 246: {'neg': 0.074, 'neu': 0.809, 'pos': 0.117, 'compound': 0.0772}
# cleaned_comment 247: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 248: {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.3818}
# cleaned_comment 249: {'neg': 0.284, 'neu': 0.608, 'pos': 0.108, 'compound': -0.7783}
# cleaned_comment 250: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 251: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 252: {'neg': 0.104, 'neu': 0.761, 'pos': 0.135, 'compound': 0.836}
# cleaned_comment 253: {'neg': 0.636, 'neu': 0.364, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 254: {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.3182}
# cleaned_comment 255: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 256: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}
# cleaned_comment 257: {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.5994}
# cleaned_comment 258: {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'compound': -0.5994}
# cleaned_comment 259: {'neg': 0.061, 'neu': 0.903, 'pos': 0.035, 'compound': -0.2023}
# cleaned_comment 260: {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3818}
# cleaned_comment 261: {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.6486}
# cleaned_comment 262: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 263: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 264: {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.5267}
# cleaned_comment 265: {'neg': 0.0, 'neu': 0.309, 'pos': 0.691, 'compound': 0.8807}
# cleaned_comment 266: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 267: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 268: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 269: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 270: {'neg': 0.066, 'neu': 0.812, 'pos': 0.123, 'compound': 0.5106}
# cleaned_comment 271: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 272: {'neg': 0.143, 'neu': 0.677, 'pos': 0.18, 'compound': 0.128}
# cleaned_comment 273: {'neg': 0.318, 'neu': 0.682, 'pos': 0.0, 'compound': -0.1027}
# cleaned_comment 274: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 275: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 276: {'neg': 0.061, 'neu': 0.671, 'pos': 0.268, 'compound': 0.7579}
# cleaned_comment 277: {'neg': 0.107, 'neu': 0.676, 'pos': 0.217, 'compound': 0.6249}
# cleaned_comment 278: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 279: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 280: {'neg': 0.176, 'neu': 0.534, 'pos': 0.29, 'compound': 0.3612}
# cleaned_comment 281: {'neg': 0.066, 'neu': 0.87, 'pos': 0.064, 'compound': -0.0258}
# cleaned_comment 282: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 283: {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.5267}
# cleaned_comment 284: {'neg': 0.124, 'neu': 0.644, 'pos': 0.233, 'compound': 0.296}
# cleaned_comment 285: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 286: {'neg': 0.244, 'neu': 0.57, 'pos': 0.187, 'compound': -0.2732}
# cleaned_comment 287: {'neg': 0.187, 'neu': 0.65, 'pos': 0.163, 'compound': -0.0772}
# cleaned_comment 288: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 289: {'neg': 0.103, 'neu': 0.598, 'pos': 0.299, 'compound': 0.5574}
# cleaned_comment 290: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 291: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 292: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.34}
# cleaned_comment 293: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 294: {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# cleaned_comment 295: {'neg': 0.055, 'neu': 0.778, 'pos': 0.167, 'compound': 0.5994}
# cleaned_comment 296: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 297: {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.6369}
# cleaned_comment 298: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 299: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 300: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 301: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5574}
# cleaned_comment 302: {'neg': 0.341, 'neu': 0.607, 'pos': 0.051, 'compound': -0.802}
# cleaned_comment 303: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 304: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 305: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 306: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 307: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 308: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 309: {'neg': 0.062, 'neu': 0.649, 'pos': 0.288, 'compound': 0.8126}
# cleaned_comment 310: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 311: {'neg': 0.0, 'neu': 0.353, 'pos': 0.647, 'compound': 0.6705}
# cleaned_comment 312: {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# cleaned_comment 313: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 314: {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}
# cleaned_comment 315: {'neg': 0.0, 'neu': 0.145, 'pos': 0.855, 'compound': 0.7096}
# cleaned_comment 316: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 317: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 318: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 319: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 320: {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.8555}
# cleaned_comment 321: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 322: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 323: {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.0772}
# cleaned_comment 324: {'neg': 0.145, 'neu': 0.756, 'pos': 0.1, 'compound': -0.5267}
# cleaned_comment 325: {'neg': 0.73, 'neu': 0.27, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 326: {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.7906}
# cleaned_comment 327: {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.4404}
# cleaned_comment 328: {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.5267}
# cleaned_comment 329: {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.2411}
# cleaned_comment 330: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 331: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 332: {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.3612}
# cleaned_comment 333: {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5719}
# cleaned_comment 334: {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4215}
# cleaned_comment 335: {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.8481}
# cleaned_comment 336: {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.8402}
# cleaned_comment 337: {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 338: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 339: {'neg': 0.422, 'neu': 0.367, 'pos': 0.211, 'compound': -0.3182}
# cleaned_comment 340: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4404}
# cleaned_comment 341: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}
# cleaned_comment 342: {'neg': 0.068, 'neu': 0.681, 'pos': 0.251, 'compound': 0.7906}
# cleaned_comment 343: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 344: {'neg': 0.069, 'neu': 0.836, 'pos': 0.095, 'compound': 0.2263}
# cleaned_comment 345: {'neg': 0.122, 'neu': 0.51, 'pos': 0.369, 'compound': 0.743}
# cleaned_comment 346: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 347: {'neg': 0.0, 'neu': 0.586, 'pos': 0.414, 'compound': 0.8625}
# cleaned_comment 348: {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.7096}
# cleaned_comment 349: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6369}
# cleaned_comment 350: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 351: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 352: {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.0572}
# cleaned_comment 353: {'neg': 0.055, 'neu': 0.798, 'pos': 0.147, 'compound': 0.7725}
# cleaned_comment 354: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 355: {'neg': 0.0, 'neu': 0.487, 'pos': 0.513, 'compound': 0.9136}
# cleaned_comment 356: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 357: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 358: {'neg': 0.033, 'neu': 0.688, 'pos': 0.28, 'compound': 0.9661}
# cleaned_comment 359: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 360: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
# cleaned_comment 361: {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.2263}
# cleaned_comment 362: {'neg': 0.0, 'neu': 0.179, 'pos': 0.821, 'compound': 0.802}
# cleaned_comment 363: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 364: {'neg': 0.059, 'neu': 0.519, 'pos': 0.422, 'compound': 0.8591}
# cleaned_comment 366: {'neg': 0.0, 'neu': 0.611, 'pos': 0.389, 'compound': 0.9423}
# cleaned_comment 367: {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.5267}
# cleaned_comment 368: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 369: {'neg': 0.42, 'neu': 0.58, 'pos': 0.0, 'compound': -0.4404}
# cleaned_comment 370: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 371: {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.6486}
# cleaned_comment 372: {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.3612}
# cleaned_comment 373: {'neg': 0.192, 'neu': 0.771, 'pos': 0.037, 'compound': -0.9607}
# cleaned_comment 374: {'neg': 0.082, 'neu': 0.737, 'pos': 0.181, 'compound': 0.3565}
# cleaned_comment 375: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 376: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 377: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 378: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.8126}
# cleaned_comment 379: {'neg': 0.159, 'neu': 0.753, 'pos': 0.088, 'compound': -0.4019}
# cleaned_comment 380: {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
# cleaned_comment 381: {'neg': 0.054, 'neu': 0.657, 'pos': 0.289, 'compound': 0.875}
# cleaned_comment 382: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 383: {'neg': 0.069, 'neu': 0.867, 'pos': 0.064, 'compound': -0.0516}
# cleaned_comment 384: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 385: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 386: {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 387: {'neg': 0.535, 'neu': 0.465, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 388: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 389: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 390: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 391: {'neg': 0.129, 'neu': 0.535, 'pos': 0.336, 'compound': 0.6632}
# cleaned_comment 392: {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# cleaned_comment 393: {'neg': 0.0, 'neu': 0.378, 'pos': 0.622, 'compound': 0.9719}
# cleaned_comment 394: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 395: {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.5859}
# cleaned_comment 396: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 397: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 398: {'neg': 0.171, 'neu': 0.698, 'pos': 0.132, 'compound': -0.128}
# cleaned_comment 399: {'neg': 0.084, 'neu': 0.86, 'pos': 0.057, 'compound': -0.296}
# cleaned_comment 400: {'neg': 0.136, 'neu': 0.605, 'pos': 0.259, 'compound': 0.7096}
# cleaned_comment 401: {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.7845}
# cleaned_comment 402: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.7845}
# cleaned_comment 403: {'neg': 0.0, 'neu': 0.195, 'pos': 0.805, 'compound': 0.9081}
# cleaned_comment 404: {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.4215}
# cleaned_comment 405: {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.91}
# cleaned_comment 406: {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
# cleaned_comment 407: {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.6249}
# cleaned_comment 408: {'neg': 0.0, 'neu': 0.952, 'pos': 0.048, 'compound': 0.2023}
# cleaned_comment 409: {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6249}
# cleaned_comment 410: {'neg': 0.0, 'neu': 0.259, 'pos': 0.741, 'compound': 0.8225}
# cleaned_comment 411: {'neg': 0.228, 'neu': 0.57, 'pos': 0.203, 'compound': -0.1027}
# cleaned_comment 412: {'neg': 0.223, 'neu': 0.36, 'pos': 0.417, 'compound': 0.1779}
# cleaned_comment 413: {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.7003}
# cleaned_comment 414: {'neg': 0.0, 'neu': 0.479, 'pos': 0.521, 'compound': 0.8689}
# cleaned_comment 415: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 416: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 417: {'neg': 0.338, 'neu': 0.455, 'pos': 0.207, 'compound': -0.6808}
# cleaned_comment 418: {'neg': 0.07, 'neu': 0.746, 'pos': 0.184, 'compound': 0.5574}
# cleaned_comment 419: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 420: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.7269}
# cleaned_comment 421: {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# cleaned_comment 423: {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.7003}
# cleaned_comment 424: {'neg': 0.27, 'neu': 0.65, 'pos': 0.08, 'compound': -0.5859}
# cleaned_comment 425: {'neg': 0.286, 'neu': 0.651, 'pos': 0.063, 'compound': -0.8014}
# cleaned_comment 426: {'neg': 0.116, 'neu': 0.792, 'pos': 0.092, 'compound': -0.3182}
# cleaned_comment 427: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 428: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 429: {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}
# cleaned_comment 430: {'neg': 0.0, 'neu': 0.485, 'pos': 0.515, 'compound': 0.6486}
# cleaned_comment 431: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 432: {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.6369}
# cleaned_comment 433: {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 434: {'neg': 0.066, 'neu': 0.86, 'pos': 0.074, 'compound': 0.0772}
# cleaned_comment 435: {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'compound': -0.6124}
# cleaned_comment 436: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 438: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
# cleaned_comment 439: {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
# cleaned_comment 440: {'neg': 0.565, 'neu': 0.435, 'pos': 0.0, 'compound': -0.4404}
# cleaned_comment 441: {'neg': 0.667, 'neu': 0.333, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 442: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 443: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 445: {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'compound': -0.8625}
# cleaned_comment 446: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 447: {'neg': 0.261, 'neu': 0.425, 'pos': 0.314, 'compound': 0.2263}
# cleaned_comment 448: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 449: {'neg': 0.063, 'neu': 0.827, 'pos': 0.11, 'compound': 0.2263}
# cleaned_comment 450: {'neg': 0.061, 'neu': 0.766, 'pos': 0.172, 'compound': 0.7003}
# cleaned_comment 451: {'neg': 0.168, 'neu': 0.784, 'pos': 0.048, 'compound': -0.6705}
# cleaned_comment 452: {'neg': 0.169, 'neu': 0.782, 'pos': 0.049, 'compound': -0.5773}
# cleaned_comment 453: {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 454: {'neg': 0.287, 'neu': 0.658, 'pos': 0.055, 'compound': -0.891}
# cleaned_comment 455: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 456: {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.3724}
# cleaned_comment 457: {'neg': 0.0, 'neu': 0.565, 'pos': 0.435, 'compound': 0.9349}
# cleaned_comment 458: {'neg': 0.452, 'neu': 0.317, 'pos': 0.23, 'compound': -0.4215}
# cleaned_comment 459: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 460: {'neg': 0.0, 'neu': 0.502, 'pos': 0.498, 'compound': 0.8979}
# cleaned_comment 462: {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4215}
# cleaned_comment 463: {'neg': 0.39, 'neu': 0.505, 'pos': 0.105, 'compound': -0.7845}
# cleaned_comment 464: {'neg': 0.083, 'neu': 0.686, 'pos': 0.231, 'compound': 0.6041}
# cleaned_comment 465: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 467: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 468: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 469: {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.9042}
# cleaned_comment 470: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 471: {'neg': 0.209, 'neu': 0.479, 'pos': 0.312, 'compound': 0.6597}
# cleaned_comment 472: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 473: {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.4932}
# cleaned_comment 474: {'neg': 0.0, 'neu': 0.765, 'pos': 0.235, 'compound': 0.5574}
# cleaned_comment 475: {'neg': 0.175, 'neu': 0.825, 'pos': 0.0, 'compound': -0.3252}
# cleaned_comment 476: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 477: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 478: {'neg': 0.095, 'neu': 0.785, 'pos': 0.12, 'compound': 0.1531}
# cleaned_comment 479: {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.128}
# cleaned_comment 480: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 481: {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.3412}
# cleaned_comment 482: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 483: {'neg': 0.222, 'neu': 0.556, 'pos': 0.222, 'compound': 0.0}
# cleaned_comment 484: {'neg': 0.0, 'neu': 0.907, 'pos': 0.093, 'compound': 0.765}
# cleaned_comment 485: {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.4588}
# cleaned_comment 486: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}
# cleaned_comment 487: {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4215}
# cleaned_comment 488: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 489: {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.7351}
# cleaned_comment 490: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 491: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 492: {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.765}
# cleaned_comment 493: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.34}
# cleaned_comment 494: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# cleaned_comment 495: {'neg': 0.522, 'neu': 0.261, 'pos': 0.217, 'compound': -0.5423}
# cleaned_comment 496: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 497: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 498: {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 499: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 500: {'neg': 0.074, 'neu': 0.828, 'pos': 0.099, 'compound': 0.4657}
# cleaned_comment 501: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 502: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.7906}
# cleaned_comment 503: {'neg': 0.035, 'neu': 0.965, 'pos': 0.0, 'compound': -0.128}
# cleaned_comment 504: {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
# cleaned_comment 505: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 506: {'neg': 0.035, 'neu': 0.848, 'pos': 0.117, 'compound': 0.8442}
# cleaned_comment 507: {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3612}
# cleaned_comment 508: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 509: {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.8625}
# cleaned_comment 510: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
# cleaned_comment 511: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 512: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 513: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 514: {'neg': 0.254, 'neu': 0.61, 'pos': 0.136, 'compound': -0.3612}
# cleaned_comment 515: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6908}
# cleaned_comment 516: {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}
# cleaned_comment 517: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 518: {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'compound': 0.6249}
# cleaned_comment 519: {'neg': 0.208, 'neu': 0.528, 'pos': 0.264, 'compound': 0.128}
# cleaned_comment 520: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 521: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 522: {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 523: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# cleaned_comment 524: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 525: {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.5719}
# cleaned_comment 526: {'neg': 0.792, 'neu': 0.208, 'pos': 0.0, 'compound': -0.5859}
# cleaned_comment 527: {'neg': 0.174, 'neu': 0.72, 'pos': 0.106, 'compound': -0.4215}
# cleaned_comment 528: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 529: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 530: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 531: {'neg': 0.37, 'neu': 0.462, 'pos': 0.168, 'compound': -0.7906}
# cleaned_comment 532: {'neg': 0.101, 'neu': 0.745, 'pos': 0.154, 'compound': 0.25}
# cleaned_comment 533: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 534: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 535: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 536: {'neg': 0.086, 'neu': 0.815, 'pos': 0.099, 'compound': 0.0772}
# cleaned_comment 537: {'neg': 0.094, 'neu': 0.763, 'pos': 0.143, 'compound': 0.6124}
# cleaned_comment 538: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 539: {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.5859}
# cleaned_comment 540: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 541: {'neg': 0.121, 'neu': 0.742, 'pos': 0.137, 'compound': -0.0772}
# cleaned_comment 542: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 543: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 544: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 545: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 546: {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.7269}
# cleaned_comment 547: {'neg': 0.255, 'neu': 0.438, 'pos': 0.307, 'compound': 0.1779}
# cleaned_comment 548: {'neg': 0.084, 'neu': 0.75, 'pos': 0.166, 'compound': 0.3818}
# cleaned_comment 550: {'neg': 0.049, 'neu': 0.951, 'pos': 0.0, 'compound': -0.5574}
# cleaned_comment 551: {'neg': 0.101, 'neu': 0.822, 'pos': 0.077, 'compound': -0.2263}
# cleaned_comment 552: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 553: {'neg': 0.076, 'neu': 0.87, 'pos': 0.054, 'compound': -0.0459}
# cleaned_comment 554: {'neg': 0.281, 'neu': 0.652, 'pos': 0.067, 'compound': -0.8043}
# cleaned_comment 555: {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 556: {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.1779}
# cleaned_comment 557: {'neg': 0.032, 'neu': 0.889, 'pos': 0.079, 'compound': 0.4939}
# cleaned_comment 558: {'neg': 0.152, 'neu': 0.645, 'pos': 0.203, 'compound': 0.0258}
# cleaned_comment 559: {'neg': 0.207, 'neu': 0.533, 'pos': 0.26, 'compound': -0.0258}
# cleaned_comment 560: {'neg': 0.397, 'neu': 0.441, 'pos': 0.162, 'compound': -0.3818}
# cleaned_comment 561: {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.5574}
# cleaned_comment 563: {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.7783}
# cleaned_comment 564: {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6369}
# cleaned_comment 565: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 566: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 567: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 568: {'neg': 0.238, 'neu': 0.671, 'pos': 0.091, 'compound': -0.6597}
# cleaned_comment 569: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 570: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 571: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# cleaned_comment 572: {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
# cleaned_comment 573: {'neg': 0.173, 'neu': 0.732, 'pos': 0.094, 'compound': -0.7273}
# cleaned_comment 574: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# cleaned_comment 575: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 576: {'neg': 0.066, 'neu': 0.804, 'pos': 0.13, 'compound': 0.4019}
# cleaned_comment 577: {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.802}
# cleaned_comment 578: {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}
# cleaned_comment 579: {'neg': 0.226, 'neu': 0.714, 'pos': 0.06, 'compound': -0.8126}
# cleaned_comment 580: {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# cleaned_comment 581: {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.6124}
# cleaned_comment 583: {'neg': 0.689, 'neu': 0.311, 'pos': 0.0, 'compound': -0.9022}
# cleaned_comment 584: {'neg': 0.157, 'neu': 0.843, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 585: {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'compound': -0.4588}
# cleaned_comment 586: {'neg': 0.075, 'neu': 0.734, 'pos': 0.191, 'compound': 0.8519}
# cleaned_comment 587: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.34}
# cleaned_comment 589: {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
# cleaned_comment 590: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 591: {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.296}
# cleaned_comment 592: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 593: {'neg': 0.464, 'neu': 0.536, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 594: {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
# cleaned_comment 595: {'neg': 0.0, 'neu': 0.505, 'pos': 0.495, 'compound': 0.5994}
# cleaned_comment 596: {'neg': 0.134, 'neu': 0.721, 'pos': 0.145, 'compound': 0.2263}
# cleaned_comment 597: {'neg': 0.053, 'neu': 0.806, 'pos': 0.142, 'compound': 0.4939}
# cleaned_comment 598: {'neg': 0.27, 'neu': 0.73, 'pos': 0.0, 'compound': -0.743}
# cleaned_comment 599: {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6369}
# cleaned_comment 600: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# cleaned_comment 601: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 602: {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'compound': -0.5267}
# cleaned_comment 603: {'neg': 0.431, 'neu': 0.294, 'pos': 0.275, 'compound': -0.1531}
# cleaned_comment 604: {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4404}
# cleaned_comment 605: {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# cleaned_comment 606: {'neg': 0.071, 'neu': 0.86, 'pos': 0.07, 'compound': -0.2732}
# cleaned_comment 607: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.5859}
# cleaned_comment 608: {'neg': 0.22, 'neu': 0.455, 'pos': 0.325, 'compound': 0.4548}
# cleaned_comment 609: {'neg': 0.0, 'neu': 0.595, 'pos': 0.405, 'compound': 0.5267}
# cleaned_comment 610: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 611: {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'compound': 0.836}
# cleaned_comment 612: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 613: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 614: {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 615: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 616: {'neg': 0.339, 'neu': 0.521, 'pos': 0.141, 'compound': -0.5859}
# cleaned_comment 617: {'neg': 0.274, 'neu': 0.366, 'pos': 0.36, 'compound': 0.34}
# ...
# cleaned_comment 33282: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33283: {'neg': 0.363, 'neu': 0.637, 'pos': 0.0, 'compound': -0.5719}
# cleaned_comment 33284: {'neg': 0.0, 'neu': 0.524, 'pos': 0.476, 'compound': 0.656}
# cleaned_comment 33285: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33286: {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.3612}
# cleaned_comment 33287: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33288: {'neg': 0.248, 'neu': 0.297, 'pos': 0.455, 'compound': 0.2732}
# cleaned_comment 33289: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33290: {'neg': 0.524, 'neu': 0.476, 'pos': 0.0, 'compound': -0.296}
# cleaned_comment 33291: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33292: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5994}
# cleaned_comment 33293: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.2023}
# cleaned_comment 33294: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33295: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 33296: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33297: {'neg': 0.0, 'neu': 0.491, 'pos': 0.509, 'compound': 0.9493}
# cleaned_comment 33298: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33299: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33300: {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# cleaned_comment 33301: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33302: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# cleaned_comment 33303: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33304: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33305: {'neg': 0.565, 'neu': 0.435, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33306: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33307: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33308: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33309: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}
# cleaned_comment 33310: {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33311: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33312: {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33313: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33314: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33315: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33316: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33317: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33318: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33319: {'neg': 0.0, 'neu': 0.504, 'pos': 0.496, 'compound': 0.7096}
# cleaned_comment 33320: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}
# cleaned_comment 33321: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33322: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33323: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33324: {'neg': 0.121, 'neu': 0.606, 'pos': 0.273, 'compound': 0.5423}
# cleaned_comment 33325: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33326: {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# cleaned_comment 33327: {'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.6908}
# cleaned_comment 33328: {'neg': 0.271, 'neu': 0.729, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33329: {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
# cleaned_comment 33330: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33331: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33332: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33333: {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# cleaned_comment 33334: {'neg': 0.277, 'neu': 0.516, 'pos': 0.206, 'compound': -0.0258}
# cleaned_comment 33335: {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.3818}
# cleaned_comment 33336: {'neg': 0.056, 'neu': 0.84, 'pos': 0.104, 'compound': 0.296}
# cleaned_comment 33337: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33338: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33339: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33340: {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}
# cleaned_comment 33341: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33342: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33343: {'neg': 0.086, 'neu': 0.736, 'pos': 0.178, 'compound': 0.3612}
# cleaned_comment 33344: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33345: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33346: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33347: {'neg': 0.212, 'neu': 0.788, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 33348: {'neg': 0.047, 'neu': 0.82, 'pos': 0.132, 'compound': 0.5719}
# cleaned_comment 33349: {'neg': 0.215, 'neu': 0.407, 'pos': 0.378, 'compound': 0.4215}
# cleaned_comment 33350: {'neg': 0.127, 'neu': 0.797, 'pos': 0.076, 'compound': -0.3182}
# cleaned_comment 33351: {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 33352: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33353: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33354: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33355: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33356: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33357: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33358: {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.6705}
# cleaned_comment 33359: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33360: {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4939}
# cleaned_comment 33361: {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compound': -0.25}
# cleaned_comment 33362: {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 33363: {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.5859}
# cleaned_comment 33364: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33365: {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33366: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33367: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33368: {'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.4019}
# cleaned_comment 33369: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33370: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# cleaned_comment 33371: {'neg': 0.097, 'neu': 0.728, 'pos': 0.175, 'compound': 0.1531}
# cleaned_comment 33372: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33373: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33374: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33375: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33376: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33377: {'neg': 0.127, 'neu': 0.746, 'pos': 0.127, 'compound': 0.0}
# cleaned_comment 33378: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33379: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33380: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33381: {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.0772}
# cleaned_comment 33382: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33383: {'neg': 0.079, 'neu': 0.606, 'pos': 0.315, 'compound': 0.7783}
# cleaned_comment 33384: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33385: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33386: {'neg': 0.0, 'neu': 0.736, 'pos': 0.264, 'compound': 0.7003}
# cleaned_comment 33387: {'neg': 0.623, 'neu': 0.377, 'pos': 0.0, 'compound': -0.5106}
# cleaned_comment 33388: {'neg': 0.296, 'neu': 0.62, 'pos': 0.084, 'compound': -0.7013}
# cleaned_comment 33389: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33390: {'neg': 0.289, 'neu': 0.56, 'pos': 0.151, 'compound': -0.5994}
# cleaned_comment 33391: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33392: {'neg': 0.671, 'neu': 0.329, 'pos': 0.0, 'compound': -0.802}
# cleaned_comment 33393: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33394: {'neg': 0.565, 'neu': 0.435, 'pos': 0.0, 'compound': -0.3818}
# cleaned_comment 33395: {'neg': 0.38, 'neu': 0.376, 'pos': 0.244, 'compound': -0.4404}
# cleaned_comment 33396: {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.0258}
# cleaned_comment 33397: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# cleaned_comment 33398: {'neg': 0.221, 'neu': 0.429, 'pos': 0.35, 'compound': 0.2023}
# cleaned_comment 33399: {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.7003}
# cleaned_comment 33400: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33401: {'neg': 0.38, 'neu': 0.62, 'pos': 0.0, 'compound': -0.8316}
# cleaned_comment 33402: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33403: {'neg': 0.184, 'neu': 0.184, 'pos': 0.632, 'compound': 0.8074}
# cleaned_comment 33404: {'neg': 0.683, 'neu': 0.317, 'pos': 0.0, 'compound': -0.6486}
# cleaned_comment 33405: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33406: {'neg': 0.589, 'neu': 0.411, 'pos': 0.0, 'compound': -0.6486}
# cleaned_comment 33407: {'neg': 0.265, 'neu': 0.556, 'pos': 0.179, 'compound': -0.34}
# cleaned_comment 33408: {'neg': 0.0, 'neu': 0.217, 'pos': 0.783, 'compound': 0.5574}
# cleaned_comment 33409: {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# cleaned_comment 33410: {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.5423}
# cleaned_comment 33411: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33412: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33413: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33414: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33415: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33416: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33417: {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.5574}
# cleaned_comment 33418: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33419: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33420: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33421: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33422: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# cleaned_comment 33423: {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.5106}
# cleaned_comment 33424: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33425: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33426: {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 33427: {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# cleaned_comment 33428: {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# cleaned_comment 33429: {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
# cleaned_comment 33430: {'neg': 0.124, 'neu': 0.708, 'pos': 0.168, 'compound': 0.128}
# cleaned_comment 33432: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33433: {'neg': 0.164, 'neu': 0.137, 'pos': 0.699, 'compound': 0.5994}
# cleaned_comment 33434: {'neg': 0.31, 'neu': 0.177, 'pos': 0.513, 'compound': 0.3182}
# cleaned_comment 33435: {'neg': 0.0, 'neu': 0.555, 'pos': 0.445, 'compound': 0.7922}
# cleaned_comment 33436: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33437: {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.2732}
# cleaned_comment 33438: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.5267}
# cleaned_comment 33439: {'neg': 0.773, 'neu': 0.227, 'pos': 0.0, 'compound': -0.7783}
# cleaned_comment 33440: {'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.4215}
# cleaned_comment 33441: {'neg': 0.316, 'neu': 0.408, 'pos': 0.276, 'compound': -0.1027}
# cleaned_comment 33442: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33443: {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.0772}
# cleaned_comment 33444: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}
# cleaned_comment 33445: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33446: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124}
# cleaned_comment 33447: {'neg': 0.347, 'neu': 0.267, 'pos': 0.387, 'compound': 0.0772}
# cleaned_comment 33448: {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.4019}
# cleaned_comment 33449: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33450: {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 33451: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33452: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33453: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33454: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33455: {'neg': 0.697, 'neu': 0.303, 'pos': 0.0, 'compound': -0.3182}
# cleaned_comment 33456: {'neg': 0.133, 'neu': 0.612, 'pos': 0.255, 'compound': 0.34}
# cleaned_comment 33457: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33458: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33459: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33460: {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.8225}
# cleaned_comment 33461: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33462: {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# cleaned_comment 33463: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33464: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33465: {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# cleaned_comment 33466: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33467: {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}
# cleaned_comment 33468: {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}
# cleaned_comment 33469: {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.296}
# cleaned_comment 33470: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33471: {'neg': 0.136, 'neu': 0.733, 'pos': 0.131, 'compound': -0.0258}
# cleaned_comment 33472: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33473: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33474: {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.1139}
# cleaned_comment 33475: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33476: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33477: {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# cleaned_comment 33478: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33479: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# cleaned_comment 33480: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
text_data_sorted = text_data.sort_values(by='sentiment_score')
text_data_sorted
# Out:
#            date                                         source  \
# 2789 2021-09-30  https://www.cryptocompare.com/coins/xrp/forum
# 3290 2021-07-07  https://www.cryptocompare.com/coins/xrp/forum
# 1965 2022-01-08  https://www.cryptocompare.com/coins/xrp/forum
# 6249 2021-02-05  https://www.cryptocompare.com/coins/xrp/forum
# 1451 2022-03-30  https://www.cryptocompare.com/coins/xrp/forum
# ...         ...                                            ...
# 2961 2021-09-02  https://www.cryptocompare.com/coins/xrp/forum
# 5664 2021-03-02  https://www.cryptocompare.com/coins/xrp/forum
# 3488 2021-06-11  https://www.cryptocompare.com/coins/xrp/forum
# 5665 2021-03-02  https://www.cryptocompare.com/coins/xrp/forum
# 2419 2021-11-13  https://www.cryptocompare.com/coins/xrp/forum
#
#                                                 comment  \
# 2789  PUMP dump dump dump dump dump dump dump dump d...
# 3290  What ever if they knock on my door and ask if ...
# 1965  Official SOLO distribution numbers are in!0.00...
# 6249  3bi329sjkn2 2 hours ago"For those listening to...
# 1451  OTI’m posting so there’s more than Cap’s 3 pos...
# ...                                                 ...
# 2961  Hey guys. I dont check in here much anymore. H...
# 5664  OK peeps. Make of this what you will of the be...
# 3488  Is XRP really going to break out like everyone...
# 5665  WHAT SHOULD WE EXPECT FROM A CRYPTO MARKET WIT...
# 2419  Hey all, I have not written a post here in a w...
#
#                                         cleaned_comment  sentiment_score
# 2789  pump dump dump dump dump dump dump dump dump d...          -0.9983
# 3290  ever knock door ask want shot shot face fuck s...          -0.9873
# 1965  offici solo distribut number solo per xrpthi c...          -0.9842
# 6249  bi sjkn hour ago listen cap doesnt track recor...          -0.9840
# 1451  oti post cap post day wrong mani jab month ago...          -0.9806
# ...                                                 ...              ...
# 2961  hey guy dont check much anymor hope everyon pr...           0.9865
# 5664  ok peep make explan howey test think determin ...           0.9890
# 3488  xrp realli go break like everyon say best stic...           0.9897
# 5665  expect crypto market gari gensler head secur e...           0.9933
# 2419  hey written post think time end year approach ...           0.9936
#
# [39319 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Group the data by date and calculate the mean sentiment score for each group
grouped = text_data.groupby('date').mean()

# Create a bar plot of the mean sentiment scores for each group
plt.bar(grouped.index, grouped['sentiment_score'])
plt.xlabel('Date')
plt.ylabel('Average Sentiment Score')
plt.title('Average Sentiment Score by Date')
plt.show()
